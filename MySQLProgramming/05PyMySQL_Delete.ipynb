# %%
pip install pymysql
# Out:
# Collecting pymysql
#   Downloading pymysql-1.1.2-py3-none-any.whl.metadata (4.3 kB)
# Downloading pymysql-1.1.2-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 1.7 MB/s eta 0:00:00
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.2

# %%
import pymysql

# %%
Connection=pymysql.connect(host='mysql-2026-pymyservice.c.aivencloud.com',port=16248,user='shrutika',password='AVNS_fbitqY6ltfVBj4kdNf_',database='vishudb')
print('connected to cloud MySQL successfully')
# Out:
# connected to cloud MySQL successfully

# %%
cursor=Connection.cursor()

# %%
pno=int(input('Enter plant id : '))
cnt=cursor.execute(f"delete from plants where plant_id={pno}")
Connection.commit()
if cnt>0:
  print('plants name closed successfully')
else:
  print("plant not found")
# Out:
# Enter plant id : 5
# plants name closed successfully
