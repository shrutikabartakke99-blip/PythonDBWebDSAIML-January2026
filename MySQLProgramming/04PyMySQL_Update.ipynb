# %%
pip install pymysql
# Out:
# Collecting pymysql
#   Downloading pymysql-1.1.2-py3-none-any.whl.metadata (4.3 kB)
# Downloading pymysql-1.1.2-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 2.0 MB/s eta 0:00:00
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.2

# %%
import pymysql

# %%
con=pymysql.connect(host='mysql-2026-pymyservice.c.aivencloud.com',port=16248,user='shrutika',password='AVNS_fbitqY6ltfVBj4kdNf_',database='vishudb')
print('connected to cloud MySQL successfully')
# Out:
# connected to cloud MySQL successfully

# %%
cursor=con.cursor()

# %%
no=int(input('Enter enquiry number : '))
serv=input('Enter new service : ')
# Out:
# Enter enquiry number : 2
# Enter new service : course

# %%
cnt=cursor.execute(f"update enquiries set servicetype='{serv}' where enqno={no}")

# %%
con.commit()

# %%
if cnt>0:
  print('enquiry updated successfully')
else:
  print('data not found')
# Out:
# enquiry updated successfully

# %% [markdown]
# Deposit money in account

# %%
no=int(input('Enter account number : '))
amt=float(input('Enter deposit amount : '))

cnt=cursor.execute(f"update accounts set balance=balance+{amt} where accno={no}")
con.commit()
if cnt==0:
  print("account does not exist")
else:
  print('amount deposited successfully')
# Out:
# Enter account number : 120
# Enter deposit amount : 5000
# amount deposited successfully

# %%
no=int(input('Enter account number : '))
amt=float(input('Enter withdraw amount : '))

try:
  cnt=cursor.execute(f"update accounts set balance=balance-{amt} where accno={no}")
  connection.commit()
  if cnt==0:
    print("account does not exist")
  else:
    print('amount withdrawn successfully')
except:
  print("insufficient balance")
# Out:
# Enter account number : 114
# Enter withdraw amount : 3000
# insufficient balance
