# %%
pip install pymysql
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 2.7 MB/s eta 0:00:00
# ...

# %%
import pymysql

# %%
con=pymysql.connect(host='mysql-2026-pymyservice.c.aivencloud.com',port=16248,user='shrutika',password='AVNS_fbitqY6ltfVBj4kdNf_',database='vishudb')
print('connected to cloud MySQL successfully')
# Out:
# connected to cloud MySQL successfully

# %%
curs=con.cursor()

# %%
no=int(input('Enter account number : '))
nm=input('Enter account name : ')
ty=input('Enter account type : ')
bl=float(input('Enter balance : '))
# Out:
# Enter account number : 51
# Enter account name : Sayali Zhende
# Enter account type : Current
# Enter balance : 3000

# %%
curs.execute(f"insert into accounts values({no},'{nm}','{ty}',{bl})")
# Out:
# 1

# %%
con.commit()

# %%
rno=int(input('Enter roll number : '))
snm=input('Enter student name : ')
ct=input('Enter city : ')
co=input('Enter course : ')
fs=float(input('Enter fees : '))
# Out:
# Enter roll number : 104
# Enter student name : Sakshi Pawar
# Enter city : Satara
# Enter course : Java Full Stack
# Enter fees : 10000

# %%
curs.execute(f"insert into student values({rno},'{snm}','{ct}','{co}',{fs})")
# Out:
# 1

# %%
con.commit()

# %%
no=int(input('Enter enqno number : '))
nm=input('Enter name : ')
srv=input('Enter service : ')
mob=input('Enter mobile number : ')
# Out:
# Enter enqno number : 3
# Enter name : sanika
# Enter service : workshop
# Enter mobile number : 7795455312

# %%
curs.execute(f"insert into enquiries(enqno ,enqnm,servicetype,mobno) values('{no}','{nm}','{srv}','{mob}')")
# Out:
# 1

# %%
con.commit()

# %%
con.close()
