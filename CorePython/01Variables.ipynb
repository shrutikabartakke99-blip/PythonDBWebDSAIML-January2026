# %% [markdown]
# My first notebook for testing online python

# %%
a=10
b=13
c=a+b
print(f"sum of {a} and {b} is {c}")
# Out:
# sum of 10 and 13 is 23

# %%
x=5
print(f"square of {x} is {x*x}")
# Out:
# square of 5 is 25

# %%
name="Shrutika"
print(f"Welcome {name} to the exciting world of python")
# Out:
# Welcome Shrutika to the exciting world of python

# %%
x=45.72
y=33.87
z=x+y
print(f"sum is {z}")
print(type(z))
# Out:
# sum is 79.59
# <class 'float'>
