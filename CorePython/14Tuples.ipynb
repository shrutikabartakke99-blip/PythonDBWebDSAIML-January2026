# %%
empty=()
print(type(empty))
coord=(15,25)
print(type(coord))
single=(7,)
print(type(single))
mixed=(9,'Shruti',68.14,True)
print(mixed)
print(type(mixed))
nested=((1,2),(3,4))
print(nested)
print(type(nested))
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# (9, 'Shruti', 68.14, True)
# <class 'tuple'>
# ((1, 2), (3, 4))
# <class 'tuple'>

# %%
t=(9,'Shruti',['Python','AI/ML'])
print(t)
print(type(t))
t[2].append('Data Analytics')
print(t)
# Out:
# (9, 'Shruti', ['Python', 'AI/ML'])
# <class 'tuple'>
# (9, 'Shruti', ['Python', 'AI/ML', 'Data Analytics'])

# %%
tup=(1726,'Shrutika','saving','Satara',43100.50)
print(len(tup))
# Out:
# 5

# %%
tup=('Shrutika','Prajwal','Prashant','Archana','Vishal')
print(max(tup))
print(min(tup))
# Out:
# Vishal
# Archana

# %%
for nm in tup:
  print(nm)
# Out:
# Shrutika
# Prajwal
# Prashant
# Archana
# Vishal

# %%
t=(5,1,2,4,2,7,3)
print(sorted(t))
# Out:
# [1, 2, 2, 3, 4, 5, 7]

# %%
t1=(1,2,3)
t2=(4,5,6)
t3=t1+t2
print(t3)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
print(t3[0:3])
# Out:
# (1, 2, 3)

# %% [markdown]
# Storage comparison

# %%
import sys

lst=[1,2,3,4,5]
tup=(1,2,3,4,5)

print(sys.getsizeof(lst))
print(sys.getsizeof(tup))
# Out:
# 104
# 80

# %%
tup=('Shrutika','Prashant','Prajwal','Archana','Prajwal','Vishal')
print(tup.count('Prajwal'))
print(tup.index('Shrutika'))
# Out:
# 2
# 0

# %%
import timeit

list_time=timeit.timeit('x=[1,2,3,4,5]',number=10000)
tup_time=timeit.timeit('x=(1,2,3,4,5)',number=10000)

print(list_time)
print(tup_time)
# Out:
# 0.00061830499998905
# 0.00016194299996641348
