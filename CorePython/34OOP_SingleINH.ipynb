# %%
#base class
class Shruti:
  def calcsquare(self,n):
    print(f"square is {n*n}")

# %%
#derived class
class Sakshi(Shruti):
  def calcsum(self,x,y):
    print(f"sum is {x+y}")

# %%
obj=Sakshi()

# %%
obj.calcsum(12,34)
# Out:
# sum is 46

# %%
obj.calcsquare(13)
# Out:
# square is 169
