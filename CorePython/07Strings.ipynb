# %%
nm="VishalBartakke"
#print(nm[0])
for i in range(5):
  print(nm[i])
# Out:
# V
# i
# s
# h
# a

# %%
nm=nm+"Shrutika"
print(nm)
# Out:
# VishalBartakkeShrutika

# %% [markdown]
# a new string is created

# %%
a="java"
b="java"
print(id(a))
print(id(b))
print(id(a)==id(b))
# Out:
# 137082972455440
# 137082972455440
# True

# %% [markdown]
# performance optimization thru shared memory

# %%
#reference based storage
x='machine learning'
y=x
print(id(x)==id(y))
# Out:
# True

# %%
s="artificial intelligence"
print(s[3:9])
# Out:
# ificia

# %%
nm="सोहमग्लोबल"
print(nm)
# Out:
# सोहमग्लोबल

# %% [markdown]
# python strings support unicode characters

# %%
a='python'
b="spring boot"
c="""
Climate change refers to the long-term alteration of Earth’sclimate patterns, primarily driven by human activities such as
burning fossil fuels, deforestation, and industrial processes that release greenhouse gases into the atmosphere. These gases
trap heat, causing global temperatures to rise, which in turn leads to melting glaciers,rising sea levels, more frequent extreme
weather events, and disruptionsto ecosystems and agriculture. While natural factors like volcanic activityand solar variations also
influence climate, the rapid changes observed since the mid-20th century are overwhelmingly linked to human activity, making
climate change one of the most urgent environmental challenges of our time.
"""
d=str(50)

print(c)
# Out:
# Climate change refers to the long-term alteration of Earth’sclimate patterns, primarily driven by human activities such as
# burning fossil fuels, deforestation, and industrial processes that release greenhouse gases into the atmosphere. These gases
# trap heat, causing global temperatures to rise, which in turn leads to melting glaciers,rising sea levels, more frequent extreme
# weather events, and disruptionsto ecosystems and agriculture. While natural factors like volcanic activityand solar variations also
# influence climate, the rapid changes observed since the mid-20th century are overwhelmingly linked to human activity, making
# climate change one of the most urgent environmental challenges of our time.

# %%
nm="Have a Beautiful Day"
print(nm.upper())
print(nm.lower())
print(nm.capitalize())
print(nm.title())
print(nm.swapcase())
# Out:
# HAVE A BEAUTIFUL DAY
# have a beautiful day
# Have a beautiful day
# Have A Beautiful Day
# hAVE A bEAUTIFUL dAY

# %%
nm="Soham global"
print(len(nm))
print(max(nm))  # 111
print(min(nm))  # space is smallest ASCII 32
print(nm.count('a'))
s="technology is power technology is future AI is a technology"
print(s.count('is'))
# Out:
# 12
# o
#
# 2
# 3

# %% [markdown]
# Searching

# %%
print("python".find("t"))
nm="springboot"
print(nm.startswith("sp"))
print(nm.endswith("on"))
# Out:
# 2
# True
# False

# %% [markdown]
# checking

# %%
print("123".isdigit())
print("abc123".isalpha())
print("abc123".isalnum())
print("soham".isupper())
print("soham".islower())
print("   ".isspace())
# Out:
# True
# False
# True
# False
# True
# True

# %% [markdown]
# replacing

# %%
s="you will never walk alone"
s=s.replace("walk","talk")
print(s)
# Out:
# you will never talk alone

# %%
s="    python    "

if s.strip()=="python":
  print("yes")
else:
  print("no")
print("   python".lstrip())
print("   python   ".rstrip())
# Out:
# yes
# python
#    python

# %%
s="you will never walk alone"
print(s.split())
film="the matrix,1999,action,wachowskys,keanu reeves,8.9"
print(film.split(","))
# Out:
# ['you', 'will', 'never', 'walk', 'alone']
# ['the matrix', '1999', 'action', 'wachowskys', 'keanu reeves', '8.9']

# %%
print("->".join(["Python","ML","DL","AI"]))
# Out:
# Python->ML->DL->AI

# %%
print("python".center(10,"*"))
print("python".ljust(10,"-"))
print("python".rjust(10,"-"))
# Out:
# **python**
# python----
# ----python

# %%
marks=45
print("my marks are %d" %marks)
print(f"my marks are {marks}")
print("My marks are {}".format(marks))
# Out:
# my marks are 45
# my marks are 45
# My marks are 45

# %%
print("Shruti"+"Bartakke")
# Out:
# ShrutiBartakke

# %%
print("-"*30)
# Out:
# ------------------------------

# %%
s="python"
b=s.encode()
print(b)

print(b.decode())
# Out:
# b'python'
# python
