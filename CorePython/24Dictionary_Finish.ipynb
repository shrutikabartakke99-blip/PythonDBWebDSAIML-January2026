# %%
dic={101: 'suhani', 102: 'sneha', 103: 'nupur', 104: 'sayali', 105: 'kajal'}
print(dic)

# %%
if 106 in dic:
  print(dic[103])
else:
  print('key not found')

# %%
company={
    "IT":{
        "manager":"shruti",
        "employees":["sanika","monika","anvi","siddhi"]
    },
    "HR":{
        "manager":"sakshi",
        "employees":["anamika","manali","rita"]
    }
}

# %%
print(company["IT"])
# Out:
# {'manager': 'shruti', 'employees': ['sanika', 'monika', 'anvi', 'siddhi']}

# %%
print(company["IT"]["manager"])
# Out:
# shruti

# %%
print(company["IT"]["employees"])
# Out:
# ['sanika', 'monika', 'anvi', 'siddhi']

# %%
print(company["IT"]["employees"][0])
# Out:
# sanika

# %%
for nm in company["IT"]["employees"]:
  print(nm.upper())
# Out:
# SANIKA
# MONIKA
# ANVI
# SIDDHI
