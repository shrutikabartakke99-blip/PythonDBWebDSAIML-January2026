# %%
tech={'python','java','jpa','spring','pandas','openai','spring','jpa'}
print(tech)
print(type(tech))
# Out:
# {'python', 'pandas', 'spring', 'openai', 'jpa', 'java'}
# <class 'set'>

# %%
empty=set()
print(type(empty))
# Out:
# <class 'set'>

# %%
mixed={8,"shruti",76.00,True}

# %%
mixed.add('8446461654')

# %%
print(mixed)
# Out:
# {True, '8446461654', 8, 76.0, 'shruti'}

# %%
mixed.remove(True)
print(mixed)
# Out:
# {'8446461654', 8, 76.0, 'shruti'}

# %%
import sys

s={1,2,3,4,5}
l=[1,2,3,4,5]
t=(1,2,3,4,5)
r=range(5)

print(sys.getsizeof(s))
print(sys.getsizeof(l))
print(sys.getsizeof(t))
print(sys.getsizeof(r))
# Out:
# 472
# 104
# 80
# 48

# %%
tech={'python','java','jpa','spring','pandas','openai','spring','jpa'}
print(len(tech))
print(max(tech))
print(min(tech))
# Out:
# 6
# spring
# java
