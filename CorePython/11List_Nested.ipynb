# %%
lst=['java','python','spring','pandas',['Shruti','Vishu']]
print(lst)
# Out:
# ['java', 'python', 'spring', 'pandas', ['Shruti', 'Vishu']]

# %%
lst.append('spark')
print(lst)
# Out:
# ['java', 'python', 'spring', 'pandas', ['Shruti', 'Vishu'], 'spark']

# %%
lst[4].append('Sumoo')
print(lst)
# Out:
# ['java', 'python', 'spring', 'pandas', ['Shruti', 'Vishu', 'Sumoo'], 'spark']

# %%
profiles=[
    ['Shrutika','Sakshi','Sayali'],
    ['python','core java','spring boot'],
    ['9 june','13 january','1 january'],
    [23,10,5],
    ['london','dubai','pune']
]
#print(profiles)
for items in profiles:
  print(items)
# Out:
# ['Shrutika', 'Sakshi', 'Sayali']
# ['python', 'core java', 'spring boot']
# ['9 june', '13 january', '1 january']
# [23, 10, 5]
# ['london', 'dubai', 'pune']

# %%
print(profiles[1][2])
# Out:
# spring boot
