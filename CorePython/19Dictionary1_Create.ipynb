# %%
dic={}
print(type(dic))
dic1=dict()
print(type(dic1))
# Out:
# <class 'dict'>
# <class 'dict'>

# %%
emp={
    "empname":"Shrutika",
    "department":"Marketing",
    "location":"Satara",
    "salary":35000
}
print(emp)
print(type(emp))
# Out:
# {'empname': 'Shrutika', 'department': 'Marketing', 'location': 'Satara', 'salary': 35000}
# <class 'dict'>

# %%
stud=dict(studname='Shruti',course='Python',feespaid=False)
print(stud)
print(type(stud))
# Out:
# {'studname': 'Shruti', 'course': 'Python', 'feespaid': False}
# <class 'dict'>

# %%
e={
    "empnm":"Shruti",
    "department":"Computer Science",
    "skillset":["Python","Power BI","DS","SQL"],
    "location":"Satara"
}
print(e)
print(type(e))

# %%
player={
    "playernm":"P.V. Sindhu",
    "club":"Bharat Petroleum (BPCL)",
    "position":"Bharat Petroleum (BPCL)",
    "healthparam":{
        "age": 30,
        "height":"179 cm",
        "weight":"65 kg"
    },
    "contractends":"January 2026"

}

print(player)
print(type(player))
# Out:
# {'playernm': 'P.V. Sindhu', 'club': 'Bharat Petroleum (BPCL)', 'position': 'Bharat Petroleum (BPCL)', 'healthparam': {'age': 30, 'height': '179 cm', 'weight': '65 kg'}, 'contractends': 'January 2026'}
# <class 'dict'>

# %%
k=['patnm','age','city']
v=['Pranjali','25','Dubai']
patient=dict(zip(k,v))
print(patient)
# Out:
# {'patnm': 'Pranjali', 'age': '25', 'city': 'Dubai'}

# %%
patient['age']=25
print(patient)
# Out:
# {'patnm': 'Pranjali', 'age': 25, 'city': 'Dubai'}
