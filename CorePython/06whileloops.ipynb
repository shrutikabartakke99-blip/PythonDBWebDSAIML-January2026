# %%
n=1

while n<=5:
  print(n)
  n+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
n=1

while n!=0:
  n=int(input('Enter a number (0 to stop) : '))
  sq=n*n
  print(f'square of {n} is {sq}')
# Out:
# square of 9 is 81
# square of 12 is 144
# square of 25 is 625
# square of -27 is 729
# Enter a number (0 to stop) : 0
# square of 0 is 0

# %%
nm=''

while nm!='stop':
  nm=input('Enter name : ')
  if nm!='stop':
     print(f'welcome {nm} to python')
# Out:
# welcome Shrutika to python
# welcome Sakshi to python
# Enter name : stop

# %%
n=1

while True:
  if n==5:
    break
  print(n)
  n+=1
# Out:
# 1
# 2
# 3
# 4

# %%
i=0

while i<5:
  i+=1
  if i==3:
    continue
  print(i)
# Out:
# 1
# 2
# 4
# 5
