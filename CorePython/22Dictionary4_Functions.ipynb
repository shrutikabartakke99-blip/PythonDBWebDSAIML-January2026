# %%
student={'name':'Shrutika','qualification':'BTech','course':'Data Analytics'}
print(student)
# Out:
# {'name': 'Shrutika', 'qualification': 'BTech', 'course': 'Data Analytics'}

# %%
print(student.keys())

for k in student.keys():
  print(k)
# Out:
# dict_keys(['name', 'qualification', 'course'])
# name
# qualification
# course

# %%
print(student.values())

for v in student.values():
  print(v)
# Out:
# dict_values(['Shrutika', 'BTech', 'Data Analytics'])
# Shrutika
# BTech
# Data Analytics

# %%
print(student.items())
# Out:
# dict_items([('name', 'Shrutika'), ('qualification', 'BTech'), ('course', 'Data Analytics')])

# %%
for i in student.items():
  print(i)
# Out:
# ('name', 'Shrutika')
# ('qualification', 'BTech')
# ('course', 'Data Analytics')

# %%
subjects=['science','maths','english']
marks=dict.fromkeys(subjects,0)
print(marks)
# Out:
# {'science': 0, 'maths': 0, 'english': 0}

# %%
marks['maths']+=5
print(marks)
# Out:
# {'science': 0, 'maths': 5, 'english': 0}

# %%
marks['english']+=7
print(marks)
# Out:
# {'science': 0, 'maths': 12, 'english': 7}
