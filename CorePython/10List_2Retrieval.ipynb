# %%
films=['the matrix','pk','speed','mission impossible']
actors=['keanu reeves','amir khan','tom cruise']

# %%
films.extend(actors)
print(films)
# Out:
# ['the matrix', 'pk', 'speed', 'mission impossible', 'keanu reeves', 'amir khan', 'tom cruise']

# %%
print(films[5])
# Out:
# amir khan

# %%
print(films[1:5])
# Out:
# ['pk', 'speed', 'mission impossible', 'keanu reeves']

# %%
print(films[2:])
# Out:
# ['speed', 'mission impossible', 'keanu reeves', 'amir khan', 'tom cruise']

# %%
print(films[:4])
# Out:
# ['the matrix', 'pk', 'speed', 'mission impossible']

# %%
print(films[-1])
# Out:
# tom cruise

# %%
print(films[::-1])
# Out:
# ['tom cruise', 'amir khan', 'keanu reeves', 'mission impossible', 'speed', 'pk', 'the matrix']

# %%
print(films)
# Out:
# ['the matrix', 'pk', 'speed', 'mission impossible', 'keanu reeves', 'amir khan', 'tom cruise']
