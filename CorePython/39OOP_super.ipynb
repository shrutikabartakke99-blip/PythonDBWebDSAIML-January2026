# %%
class Shruti:
  def __init__(self,name):
    print(f"your name is {name} and length is {len(name)}")

# %%
class Sakshi(Shruti):
  def __init__(self):
    super().__init__('Sumoo')
    print("derived class sakshi constructor running")

# %%
obj=Sakshi()
# Out:
# your name is Sumoo and length is 5
# derived class sakshi constructor running
