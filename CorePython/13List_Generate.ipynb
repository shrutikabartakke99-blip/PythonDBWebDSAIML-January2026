# %%
lst=[3,12,45,9,15,26,13]
sq=[]

for n in lst:
  sq.append(n*n)

print(sq)
# Out:
# [9, 144, 2025, 81, 225, 676, 169]

# %%
lst=[9,25,45,9,15,26,12]
cubes=[n**3 for n in lst]
print(cubes)
# Out:
# [729, 15625, 91125, 729, 3375, 17576, 1728]

# %%
nms=['Shrutika','Prajwal','Prashant','Archana']
u=[nm.upper() for nm in nms]
print(u)
# Out:
# ['SHRUTIKA', 'PRAJWAL', 'PRASHANT', 'ARCHANA']

# %%
lst=[9,13,26,1,45,10,30,15,18,25]
odd=[x for x in lst if x%2==1]
print(odd)
# Out:
# [9, 13, 1, 45, 15, 25]

# %%
lst=[9,13,26,1,-45,-10,30,15,-18,25]
neg=[x for x in lst if x<0]
print(neg)
# Out:
# [-45, -10, -18]

# %%
lst=[9,13,26,1,45,10,30,15,18,25]
res=[x for x in lst if x%3==0]
print(res)
# Out:
# [9, 45, 30, 15, 18]

# %%
l1=[3,14,26,55,15]
l2=[1,5,13,2,9,26,14]
common=[x for x in l1 if x in l2]
print(common)
# Out:
# [14, 26]

# %%
l1=['java','python','sql','spring','spark','docker']
l2=['azure','aws','java','oracle','cpp']
res=[x for x in l1 if x not in l2]
res2=[x for x in l2 if x not in l1]
res.extend(res2)
print(res)
# Out:
# ['python', 'sql', 'spring', 'spark', 'docker', 'azure', 'aws', 'oracle', 'cpp']
