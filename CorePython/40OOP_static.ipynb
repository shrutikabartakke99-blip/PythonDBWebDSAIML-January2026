# %%
class Student:
  @staticmethod
  def ispass(marks):
    return marks>=35

  def thanks(self):
    print('thanks for your visit')

# %%
print(Student.ispass(12))
# Out:
# False

# %%
print(Student.ispass(76))
# Out:
# True

# %%
obj=Student()

# %%
obj.thanks()
# Out:
# thanks for your visit
