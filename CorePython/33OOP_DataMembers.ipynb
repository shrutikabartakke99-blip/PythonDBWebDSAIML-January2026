# %% [markdown]
# data member is a variable of the class whose values can be accessed across all functions of the class

# %%
class School:
  scnm='KBP school'
  def show(self,scnm):
    print(f'local- school name is {scnm}')
    print(f'global- school name is {self.scnm}')
  def display(self):
    print(self.scnm)

# %%
obj=School()

# %%
obj.show("zp school")
# Out:
# local- school name is zp school
# global- school name is KBP school

# %%
obj.display()
# Out:
# KBP school

# %%
class Player:
  def __init__(self):
    self.playernm="Not available"
    self.country="NA"
  def takedata(self):
    self.playernm=input('Enter player name : ')
    self.country=input('Enter country : ')
  def showdata(self):
    print(f"Player name is {self.playernm}")
    print(f"Country is {self.country}")

# %%
p=Player()

# %%
p.takedata()
# Out:
# Enter player name : samruddhi Botkar
# Enter country : India

# %%
p.showdata()
# Out:
# Player name is samruddhi Botkar
# Country is India

# %%
obj=Player()

# %%
obj.showdata()
# Out:
# Player name is Not available
# Country is NA
