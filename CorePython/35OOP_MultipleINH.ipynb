# %%
class One:
  def calcsquare(self,n):
    print(f"square is {n**2}")

# %%
class Two:
  def calcsum(self,x,y):
    print(f"sum is {x+y}")

# %%
class Three(One,Two):
  def calcdiscount(self,amount):
    print(f"discount will be {amount*10/100}")

# %%
obj=Three()

# %%
obj.calcdiscount(5400)
# Out:
# discount will be 540.0

# %%
obj.calcsum(45,67)
# Out:
# sum is 112

# %%
obj.calcsquare(15)
# Out:
# square is 225
