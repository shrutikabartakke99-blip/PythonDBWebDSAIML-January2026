# %%
data=bytearray(b'Python Programming')
print(f"original data : {data}")
# Out:
# original data : bytearray(b'Python Programming')

# %%
view=memoryview(data)

# %%
#view[0]=66
view[0]=ord('S')

# %%
print(f'Modified data : {data}')
# Out:
# Modified data : bytearray(b'Sython Programming')

# %% [markdown]
# Slicing without copying

# %%
slogan=bytearray(b'Technology is power')
print(slogan)
# Out:
# bytearray(b'Technology is power')

# %%
slice1=slogan[:7]
print(f"regular slicing : {slice1}")
# Out:
# regular slicing : bytearray(b'Technol')

# %%
view=memoryview(slogan)
vslice=view[2:8]
print(f"Memoryview slice : {bytes(vslice)}")
# Out:
# Memoryview slice : b'chnolo'
