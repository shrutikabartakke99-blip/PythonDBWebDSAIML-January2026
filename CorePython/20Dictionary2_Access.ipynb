# %%
student={"studnm":"Shrutika","course":"Python","fees":10000,"mode":"live online"}
print(student)
# Out:
# {'studnm': 'Shrutika', 'course': 'Python', 'fees': 10000, 'mode': 'live online'}

# %%
print(student["studnm"])
# Out:
# Shrutika

# %%
print(student["course"])
# Out:
# Python

# %%
print(student.get("mode"))
# Out:
# live online

# %%
print(student.get("mobile"))
# Out:
# None

# %%
print(student.get("qualification","Not Available"))
# Out:
# Not Available

# %%
player={
    "playernm":"Dominik Szoboszlai",
    "club":"Liverpool",
    "position":"midfielder",
    "healthparam":{
        "age":26,
        "height":175,
        "weight":64
    },
    "contractends":"June 2027"

}

# %%
print(player["healthparam"]["age"])
# Out:
# 26
