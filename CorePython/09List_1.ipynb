# %%
n=[7,26,1,15,45,30]
print(n)
print(type(n))
# Out:
# [7, 26, 1, 15, 45, 30]
# <class 'list'>

# %%
n.append(13)
print(n)
# Out:
# [7, 26, 1, 15, 45, 30, 13]

# %%
nm=[]
print(type(nm))
nm.append("python")
nm.append("spring")
nm.append("pandas")
nm.append("java")
print(nm)
# Out:
# <class 'list'>
# ['python', 'spring', 'pandas', 'java']

# %%
nm.insert(2,"mongodb")
print(nm)
# Out:
# ['python', 'spring', 'mongodb', 'pandas', 'java']

# %%
nm.remove("java")
print(nm)
# nm.clear()
# Out:
# ['python', 'spring', 'mongodb', 'pandas']

# %%
cloud=['azure','aws','gcp']
nm.extend(cloud)
print(nm)
# Out:
# ['python', 'spring', 'mongodb', 'pandas', 'azure', 'aws', 'gcp']

# %%
print(nm[3])
# Out:
# pandas

# %%
print(nm)
# Out:
# ['python', 'spring', 'mongodb', 'pandas', 'azure', 'aws', 'gcp']

# %%
#retrive and remove last element from list
print(nm.pop())
# Out:
# gcp

# %%
print(nm)
# Out:
# ['python', 'spring', 'mongodb', 'pandas', 'azure', 'aws']

# %%
nm.sort()
# nm.sort(reverse=True)
print(nm)
# Out:
# ['aws', 'azure', 'mongodb', 'pandas', 'python', 'spring']

# %%
comp=['microsoft','volkswagen','samsung','dell','hp']
comp.reverse()
print(comp)
# Out:
# ['hp', 'dell', 'samsung', 'volkswagen', 'microsoft']

# %%
for cnm in comp:
  print(cnm.capitalize())
# Out:
# Hp
# Dell
# Samsung
# Volkswagen
# Microsoft

# %%
lst=[9,'Shruti',13.26,True]
print(lst)

for item in lst:
  print(type(item))
# Out:
# [9, 'Shruti', 13.26, True]
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>
