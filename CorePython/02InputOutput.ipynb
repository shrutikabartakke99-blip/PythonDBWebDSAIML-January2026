# %% [markdown]
# Input output in Python

# %%
nm=input('Enter your name ')
# Out:
# Enter your name Shrutika Bartakke

# %%
print(f'user name is {nm}')
# Out:
# user name is Shrutika Bartakke

# %%
n=int(input('Enter a number '))
sq=n*n
print(f"square of {n} is {sq}")
# Out:
# Enter a number 20
# square of 20 is 400

# %%
n=int(input('Enter a number '))
sq=n*n
print(f"square of {n} is {sq}")
# Out:
# Enter a number 15
# square of 15 is 225

# %%
x=float(input('Enter first number '))
y=float(input('Enter second number '))
z=x+y
print(f"sum of {x} and {y} is {z}")
# Out:
# Enter first number 13
# Enter second number 12
# sum of 13.0 and 12.0 is 25.0

# %%
x=float(input('Enter first number '))
y=float(input('Enter second number '))
z=x+y
print(f"sum of {x} and {y} is {z}")
# Out:
# Enter first number 45
# Enter second number 34
# sum of 45.0 and 34.0 is 79.0

# %%
custnm=input('Enter customer name ')
amount=float(input('Enter purchase amount '))
discount=amount*10/100
net=amount-discount
print(f'Customer Name : {custnm}')
print(f'Purchase amount : {amount}')
print(f'Discount : {discount}')
print(f'Net Bill : {net}')
# Out:
# Enter customer name Shrutika Bartakke
# Enter purchase amount 40000
# Customer Name : Shrutika Bartakke
# Purchase amount : 40000.0
# Discount : 4000.0
# Net Bill : 36000.0

# %%
nm=input('Enter Name ')
amount=float(input('Enter Amount '))
Discount=amount*5/100
net=amount-Discount
print(f'Name : {nm}')
print(f'Purchase Amount : {amount}')
print(f'Discount : {Discount}')
print(f'Net Bill : {net}')
# Out:
# Enter Name Suhani
# Enter Amount 5400
# Name : Suhani
# Purchase Amount : 5400.0
# Discount : 270.0
# Net Bill : 5130.0
