# %%
n=int(input('Enter a number : '))
sq=n*n
print(f"square of {n} is {sq}")
# Out:
# Enter a number : Shruti
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1355/174603815.py in <cell line: 0>()
# ----> 1 n=int(input('Enter a number : '))
#       2 sq=n*n
#       3 print(f"square of {n} is {sq}")
#
# ValueError: invalid literal for int() with base 10: 'Shruti'

# %% [markdown]
# Exception Handling

# %%
try:
  n=int(input('Enter a number : '))
except:
  print("Invalid input...please enter a number")
  n=0

sq=n**2
print(f"square of {n} is {sq}")
# Out:
# Enter a number : Shruti
# Invalid input...please enter a number
# square of 0 is 0

# %%
custnm=input('Enter customer name : ')

try:
  purchamt=float(input('Enter purchase amount : '))
except ValueError:
  print('invalid purchase amount')
  purchamt=0

discount=purchamt*15/100
bill=purchamt-discount

print(f"{custnm}, your net bill is {bill}")
# Out:
# Enter customer name : shrutika
# Enter purchase amount : 12500
# shrutika, your net bill is 10625.0

# %%
try:
  x=int(input('Enter first number '))
  y=int(input('Enter second number '))
  res=x/y
except ValueError:
  res=0
  print('Invalid input')
except ZeroDivisionError:
  res=x
  print('cant divide by zero')

print(f'result of division is {res}')
# Out:
# Enter first number 15
# Enter second number 20
# result of division is 0.75

# %%
try:
  x=int(input('Enter first number '))
  y=int(input('Enter second number '))
  res=x/y
except:
  res=0
  print('Invalid input or divided by zero')

print(f'result of division is {res}')
# Out:
# Enter first number 12
# Enter second number 0
# Invalid input or divided by zero
# result of division is 0

# %%
film={
    "name":"sholay",
    "releaseyear":1975,
    "genre":"action",
    "language":"hindi",
    "actors":["amitabh bachchan","dharmendra","sanjiv kumar"],
    "music":"r d burman",
    "imdbrating":7.9
}

# %%
key=input('Enter key : ')
try:
  print(film[key])
except KeyError:
  print(f'information not available for {key}')
finally:
  print('films make our life live')
# Out:
# Enter key :  actresses
# information not available for  actresses
# films make our life live

# %%
lst=['java','spring','python','data science','machine learning','genai','pandas']

# %%
try:
  i=int(input('Enter list index : '))
  print(lst[i])
except ValueError:
  print('invalid index...must be a number')
except IndexError:
  print('Index value out of range')
# Out:
# Enter list index : 2
# python

# %%
try:
  i=int(input('Enter list index : '))
  try:
    print(lst[i])
  except IndexError:
    print('index out of range')
except ValueError:
  print('invalid index...must be a number')
# Out:
# Enter list index : 9
# index out of range

# %%
try:
  n=int(input("Enter a number : "))
  if n<0:
    raise ValueError()
except ValueError:
  n=0
  print('Invalid input or a negative number')

sq=n**2
print(f'square of {n} is {sq}')
# Out:
# Enter a number : -27
# Invalid input or a negative number
# square of 0 is 0

# %%
try:
  ps=input('Enter password : ')
  if len(ps)<8:
    raise ValueError()
except ValueError:
  print('invalid password')

print(f"your password is {ps}")
# Out:
# Enter password : Shruti
# invalid password
# your password is Shruti
