# %%
class Employee:
  def __init__(self):
    print("welcome to SohamGlobal")
  def calcsalary(self,basic):
    allowances=int(basic*45/100)
    tax=int(basic*5/100)
    netsalary=basic+allowances-tax
    print(f"Net Salary : {netsalary}")
  def __del__(self):
    print('Object destroyed from the memory')

# %%
e=Employee()
# Out:
# welcome to SohamGlobal

# %%
e.calcsalary(41500)
# Out:
# Net Salary : 58100

# %%
e1=Employee()
e1.calcsalary(25000)
# Out:
# welcome to SohamGlobal
# Net Salary : 35000

# %%
e.calcsalary(51000)
# Out:
# Net Salary : 71400
