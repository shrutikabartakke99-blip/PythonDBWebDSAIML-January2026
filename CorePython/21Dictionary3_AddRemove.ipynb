# %%
tech={'os':'windows','language':'python','database':'oracle'}
print(tech)
# Out:
# {'os': 'windows', 'language': 'python', 'database': 'oracle'}

# %%
tech['cloud']='aws'
print(tech)
# Out:
# {'os': 'windows', 'language': 'python', 'database': 'oracle', 'cloud': 'aws'}

# %%
tech['database']='mongodb'
print(tech)
# Out:
# {'os': 'windows', 'language': 'python', 'database': 'mongodb', 'cloud': 'aws'}

# %%
tech.update({'framework':'springboot','aiplatform':'deepseek'})
print(tech)
# Out:
# {'os': 'windows', 'language': 'python', 'database': 'mongodb', 'cloud': 'aws', 'framework': 'springboot', 'aiplatform': 'deepseek'}

# %%
tech['experience']=5
print(tech)
# Out:
# {'os': 'windows', 'language': 'python', 'database': 'mongodb', 'cloud': 'aws', 'framework': 'springboot', 'aiplatform': 'deepseek', 'experience': 5}

# %%
tech['experience']+=2
print(tech)
# Out:
# {'os': 'windows', 'language': 'python', 'database': 'mongodb', 'cloud': 'aws', 'framework': 'springboot', 'aiplatform': 'deepseek', 'experience': 7}

# %% [markdown]
# **remove**

# %%
del tech['os']

# %%
print(tech)
# Out:
# {'language': 'python', 'database': 'mongodb', 'cloud': 'aws', 'framework': 'springboot', 'aiplatform': 'deepseek', 'experience': 7}

# %%
f=tech.pop('framework')
print(f)
print(tech)
# Out:
# springboot
# {'language': 'python', 'database': 'mongodb', 'cloud': 'aws', 'aiplatform': 'deepseek', 'experience': 7}

# %%
tech.clear()

# %%
print(tech)
# Out:
# {}

# %%
tech["language"]="python"
tech["framework"]="django"
tech["database"]="mysql"
print(tech)
# Out:
# {'language': 'python', 'framework': 'django', 'database': 'mysql'}
